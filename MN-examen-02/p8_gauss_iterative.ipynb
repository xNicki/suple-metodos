# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Ejercicio 1

# %%
# %autoreload 2
from src import gauss_jacobi, gauss_seidel
A = [[2,1],[3,2]]
b = [5,8]

gauss_seidel(A = A, b = b, x=[0,0])
print("\n")
gauss_jacobi(A = A, b = b, x=[0,0])
# Out:
# [02-12 15:04:26][INFO][USUARIO] i= 0 x: [[0. 0.]]
# [02-12 15:04:26][INFO][USUARIO] i= 1 x: [[2.5  0.25]]
# [02-12 15:04:26][INFO][USUARIO] i= 2 x: [[2.375  0.4375]]
# [02-12 15:04:26][INFO][USUARIO] i= 3 x: [[2.28125  0.578125]]
# [02-12 15:04:26][INFO][USUARIO] i= 4 x: [[2.2109375  0.68359375]]
# [02-12 15:04:26][INFO][USUARIO] i= 5 x: [[2.15820312 0.76269531]]
#
#
# [02-12 15:04:26][INFO][USUARIO] i= 0 x: [[0. 0.]]
# [02-12 15:04:26][INFO][USUARIO] i= 5 x: [[2.28125 2.6875 ]]
# array([[2.28125],
#        [2.6875 ]])

# %%
# Extraer valores de la trayectoria
# -- Datos de ejemplo --
x_values = [0, 2.5, 2.375, 2.28125, 2.2109375, 2.15820312]
y_values = [0, 0.25, 0.4375, 0.578125, 0.68359375, 0.76269531]

import matplotlib.pyplot as plt

iterations = range(len(x_values))

# Dibujar trajectoria en el espacio 2D
plt.plot(x_values, y_values, "o:", markersize=4)
plt.plot(x_values[0], y_values[0], "gd", markersize=8, label="$X_0$", alpha=0.8)
plt.plot(x_values[-1], y_values[-1], "ro", markersize=8, label="$X_{sol}$", alpha=0.8)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Trajectoria")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Ejercicio 2

# %%
# %autoreload 2
from src import gauss_jacobi, gauss_seidel
A = [[1,1],[-2,1]]
b = [6,0]

gauss_seidel(A = A, b = b, x=[0,0])
print("\n")
gauss_jacobi(A = A, b = b, x=[0,0])
# Out:
# [02-12 15:03:54][INFO][USUARIO] i= 0 x: [[0. 0.]]
# [02-12 15:03:54][INFO][USUARIO] i= 1 x: [[ 6. 12.]]
# [02-12 15:03:54][INFO][USUARIO] i= 2 x: [[ -6. -12.]]
# [02-12 15:03:54][INFO][USUARIO] i= 3 x: [[18. 36.]]
# [02-12 15:03:54][INFO][USUARIO] i= 4 x: [[-30. -60.]]
# [02-12 15:03:54][INFO][USUARIO] i= 5 x: [[ 66. 132.]]
#
#
# [02-12 15:03:54][INFO][USUARIO] i= 0 x: [[0. 0.]]
# [02-12 15:03:54][INFO][USUARIO] i= 5 x: [[ 18. -12.]]
# array([[ 18.],
#        [-12.]])

# %% [markdown]
# # Código para dibujar

# %%
# Extraer valores de la trayectoria
# -- Datos de ejemplo --
x_values = [0, 6, -6, 18, -30, 66]
y_values = [0, 12, -12, 36, -60, 132]

import matplotlib.pyplot as plt

iterations = range(len(x_values))

# Dibujar trajectoria en el espacio 2D
plt.plot(x_values, y_values, "o:", markersize=4)
plt.plot(x_values[0], y_values[0], "gd", markersize=8, label="$X_0$", alpha=0.8)
plt.plot(x_values[-1], y_values[-1], "ro", markersize=8, label="$X_{sol}$", alpha=0.8)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Trajectoria")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Reemplace con el conjunto de datos dado
# --- Datos de ejemplo
# Le quite el dato de (-200.0,500) porque es un valor atípico que no dejaba ver bien el gráfico

import numpy as np
datos =[(4.1,5.4),(3.6,5.4), (3.3,5.3), (0.2,5.0), (9.8,6.1), (9.5,6.0), (3.2,5.3), (5.8,5.5), (0.7,5.2), (4.2,5.4), (5.4,5.7), (6.3,5.7), (0.3,5.1), (1.0,5.3), (9.3,5.7), (2.4,5.2), (4.7,5.5), (8.8,6.0), (5.2,5.5), (5.6,5.7), (4.8,5.5), (9.7,6.1), (7.5,5.9), (0.7,5.1), (8.2,5.9), (0.6,5.0), (2.3,5.3), (8.4,5.6), (0.4,5.1), (1.6,5.1), (1.5,5.1), (9.6,6.0), (6.6,5.5), (0.9,5.0), (8.2,6.1), (5.5,5.5), (9.4,5.9), (4.3,5.4), (6.4,5.6), (3.3,5.5), (2.8,5.3), (3.3,5.2), (0.9,5.3), (5.8,5.7), (4.3,5.5), (1.0,5.1), (5.4,5.5), (8.0,5.9), (8.6,5.8), (4.0,5.4), (8.9,5.8), (3.0,5.4), (9.2,5.9), (3.3,5.3), (8.9,5.9), (2.3,5.1), (1.9,5.1), (3.5,5.5), (4.3,5.4), (5.8,5.5), (8.9,5.9), (0.7,5.1), (5.8,5.6), (6.2,5.7), (2.4,5.3), (1.5,5.1), (0.2,5.1), (3.1,5.3), (6.2,5.6), (4.5,5.4), (3.1,5.3), (1.3,5.1), (2.0,5.3), (0.4,5.1), (5.4,5.5), (4.6,5.6), (0.6,4.9), (1.6,5.2), (1.9,5.2), (2.2,5.4), (6.4,5.5), (1.1,5.0), (7.9,5.8), (8.1,5.6), (3.8,5.3), (1.1,4.9), (3.0,5.4), (5.6,5.6), (5.4,5.5), (0.3,5.1), (8.3,6.1), (8.5,5.8), (5.3,5.6), (1.5,5.1), (0.9,5.1), (2.7,5.3), (3.0,5.3), (8.0,5.7), (2.0,5.2), (9.4,6.0)]
xs = np.array([p[0] for p in datos])
ys = np.array([p[1] for p in datos])

max_x = max(xs)
max_y = max(ys)
print("Max x:", max_x)
print("Max y:", max_y)
# Out:
# Max x: 9.8
# Max y: 6.1

# %%
# Derivadas parciales para regresión lineal
# ####################################################################
def der_parcial_4(xs: list, ys: list) -> tuple[float, float, float]:
   
    c_4 = 0
    c_3 = 0
    c_2 = 0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        
        c_ind += xi**4 * yi
        
        c_4 += xi**8
        c_3 += xi**7
        c_2 += xi**6

        # coeficiente del parámetro 1
        c_1 += xi**5

        # coeficiente del parámetro 0
        c_0 += xi**4

    return (c_4, c_3, c_2, c_1, c_0, c_ind)

def der_parcial_3(xs: list, ys: list) -> tuple[float, float, float]:
   
    c_4 = 0
    c_3 = 0
    c_2 = 0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        
        c_ind += xi**3 * yi
        
        c_4 += xi**7
        c_3 += xi**6
        c_2 += xi**5

        # coeficiente del parámetro 1
        c_1 += xi**4

        # coeficiente del parámetro 0
        c_0 += xi**3

    return (c_4, c_3, c_2, c_1, c_0, c_ind)

def der_parcial_2(xs: list, ys: list) -> tuple[float, float, float]:
   
    c_4 = 0
    c_3 = 0
    c_2 = 0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        
        c_ind += xi**2 * yi
        
        c_4 += xi**6
        c_3 += xi**5
        c_2 += xi**4

        # coeficiente del parámetro 1
        c_1 += xi**3

        # coeficiente del parámetro 0
        c_0 += xi**2

    return (c_4, c_3, c_2, c_1, c_0, c_ind)

def der_parcial_1(xs: list, ys: list) -> tuple[float, float, float]:
   
    c_4 = 0
    c_3 = 0
    c_2 = 0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        
        c_ind += xi**1 * yi
        
        c_4 += xi**5
        c_3 += xi**4
        c_2 += xi**3

        # coeficiente del parámetro 1
        c_1 += xi**2

        # coeficiente del parámetro 0
        c_0 += xi**1

    return (c_4, c_3, c_2, c_1, c_0, c_ind)


def der_parcial_0(xs: list, ys: list) -> tuple[float, float, float]:
   
    c_4 = 0
    c_3 = 0
    c_2 = 0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        
        c_ind += xi**0 * yi
        
        c_4 += xi**4
        c_3 += xi**3
        c_2 += xi**2

        # coeficiente del parámetro 1
        c_1 += xi**1

        # coeficiente del parámetro 0
        c_0 += xi**0

    return (c_4, c_3, c_2, c_1, c_0, c_ind)

# %%
from src import ajustar_min_cuadrados

coeficientes = ajustar_min_cuadrados(
    xs,
    ys,
    [der_parcial_4, der_parcial_3, der_parcial_2, der_parcial_1, der_parcial_0]
)

a4, a3, a2, a1, a0 = coeficientes
def interpolacion(x):
    return a4*x**4 + a3*x**3 + a2*x**2 + a1*x + a0

print("Coeficientes obtenidos:", coeficientes)
print(a4, a3, a2, a1, a0 )
# UTILICE:
# ajustar_min_cuadrados()
# Out:
# [02-12 15:25:13][INFO][USUARIO] Se ajustarán 5 parámetros.
# [02-12 15:25:13][INFO][USUARIO]
# [[ 1.66563525e+05  2.08531260e+04  2.82182000e+03  4.43400000e+02
#    1.00000000e+02  5.45400000e+02]
#  [ 0.00000000e+00 -1.19087888e+06 -3.91136106e+05 -1.13767312e+05
#   -4.23698864e+04 -2.23645385e+05]
#  [ 0.00000000e+00 -1.08586894e+05 -3.66163550e+04 -1.10730630e+04
#   -4.37849326e+03 -2.30445055e+04]
#  [ 0.00000000e+00 -7.82274818e+03 -2.74461528e+03 -8.86155166e+02
#   -3.92859623e+02 -2.05712998e+03]
#  [ 0.00000000e+00 -1.20688835e+07 -3.88999756e+06 -1.10284870e+06
#   -3.96303459e+05 -2.09559028e+06]]
# [02-12 15:25:13][INFO][USUARIO]
# [[ 1.66563525e+05  2.08531260e+04  2.82182000e+03  4.43400000e+02
#    1.00000000e+02  5.45400000e+02]
#  [ 0.00000000e+00 -7.82274818e+03 -2.74461528e+03 -8.86155166e+02
#   -3.92859623e+02 -2.05712998e+03]
#  [ 0.00000000e+00  0.00000000e+00  1.48141350e+03  1.22758061e+03
#    1.07475735e+03  5.51033872e+03]
# ...

# %%
# Reemplace con la función obtenida de ajustar_min_cuadrados

interpolacion = lambda x: a4*x**4 + a3*x**3 + a2*x**2 + a1*x + a0
# --- Función de ejemplo

import matplotlib.pyplot as plt
import numpy as np

# Dibujar los puntos x, y
plt.scatter(xs, ys, alpha=0.5, label="Datos")

# Dibujar la función de aproximación
x_aprox = np.linspace(min(xs), max(xs), 100)
y_aprox = [interpolacion(xi) for xi in x_aprox]
plt.plot(x_aprox, y_aprox, "r-", label="Interpolación: y = ")

plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()

# %%
errores_relativos = []

for xi, yi in zip(xs, ys):
    y_aprox = interpolacion(xi)
    error = abs((yi - y_aprox) / yi)
    errores_relativos.append(error)


erel = sum(errores_relativos) / len(errores_relativos)
print("Error relativo prom", erel)

emax = max(errores_relativos)
print("Error rel max", emax)
# Out:
# Error relativo prom 0.013884205226049755
# Error rel max 0.047206386963217356

# %% [markdown]
# # PREGUNTA 3

# %%
import numpy as np
from scipy.optimize import bisect, newton

def f(x):
    return x**5 + 5.25*x**4 + 4.125*x**3 - 9.125*x**2 - 14.625*x - 5.625
xs = np.linspace(-6, 3, 1000)
ys = f(xs)

for i in range(len(xs)-1):
    if ys[i]*ys[i+1] < 0:
        print(xs[i], xs[i+1])


x1 = bisect(f, -4, -3)  
x2 = bisect(f, -2, 0)    
x3 = bisect(f, 1, 2)     

print(x1, x2, x3)


x1_n = newton(f, -3.8)
x2_n = newton(f, -1.2)
x3_n = newton(f, 1.6)

print(x1_n, x2_n, x3_n)

roots = np.array([x1_n, x2_n, x3_n])
roots = np.unique(np.round(roots, 6))
roots
# Out:
# -3.7567567567567566 -3.7477477477477477
# 1.4954954954954953 1.5045045045045047
# -3.75 -1.0 1.5
# -3.750000000000001 -1.0000047515523072 1.5000000000000002
# array([-3.75    , -1.000005,  1.5     ])
